# %%
import pandas as pd

# %% [markdown]
# ### OKOLI EKPEREAMAKA PYTHON QUIZ ASSIGNMENT
# Answer the following questions using the wine review dataset from previous classd
# 1.	Set the index of the dataframe to country
# 2.	Using the index and any country of your choice, show the reviews for those country
# Sample code
# df.loc[df.country == 'Italy']
# can you glean any insight from this? Perhaps the percentage of wines from the selected country.
# 3.	Supposing wines are reviewed on a 80-to-100 point scale, and wines with greater than 90 points are average, can you check what percentage of the total wines are above average? What about the percentage in the country you selected from question 2?
# 4.	Check the pandas ‘isin’ operator and use it to perform any operation of your choice on the dataset
# 5.	Suppose we'll buy any wine that's made in Italy or which is rated above average. Can you select or show these wines using the or (|) operator?
# 6.	Read about the notnull operator and use it to check for wines whose prices are not null
# 7.	Please share something you learnt outside of class on thursday

# %%
winedf = pd.read_csv("Wine_review.csv", index_col=0)

# %%
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 10 columns]

# %%
winedf1 = winedf.set_index("country")

# %%
winedf1
# Out:
#                                                description  \
# country
# US       This tremendous 100% varietal wine hails from ...
# Spain    Ripe aromas of fig, blackberry and cassis are ...
# US       Mac Watson honors the memory of a wine once ma...
# US       This spent 20 months in 30% new French oak, an...
# France   This is the top wine from La Bégude, named aft...
# ...                                                    ...
# Italy    Many people feel Fiano represents southern Ita...
# France   Offers an intriguing nose with ginger, lime an...
# Italy    This classic example comes from a cru vineyard...
# France   A perfect salmon shade, with scents of peaches...
# Italy    More Pinot Grigios should taste like this. A r...
#
#                                   designation  points  price  \
# country
# US                          Martha's Vineyard      96  235.0
# Spain    Carodorum Selección Especial Reserva      96  110.0
# US              Special Selected Late Harvest      96   90.0
# US                                    Reserve      96   65.0
# France                             La Brûlade      95   66.0
# ...                                       ...     ...    ...
# Italy                                     NaN      91   20.0
# France                         Cuvée Prestige      91   27.0
# Italy                           Terre di Dora      91   20.0
# France                        Grand Brut Rosé      90   52.0
# Italy                                     NaN      90   15.0
#
#                    province           region_1           region_2  \
# country
# US               California        Napa Valley               Napa
# Spain        Northern Spain               Toro                NaN
# US               California     Knights Valley             Sonoma
# US                   Oregon  Willamette Valley  Willamette Valley
# France             Provence             Bandol                NaN
# ...                     ...                ...                ...
# Italy        Southern Italy  Fiano di Avellino                NaN
# France            Champagne          Champagne                NaN
# Italy        Southern Italy  Fiano di Avellino                NaN
# France            Champagne          Champagne                NaN
# Italy    Northeastern Italy         Alto Adige                NaN
#
#                     variety                   winery
# country
# US       Cabernet Sauvignon                    Heitz
# Spain         Tinta de Toro  Bodega Carmen Rodríguez
# US          Sauvignon Blanc                 Macauley
# US               Pinot Noir                    Ponzi
# France   Provence red blend     Domaine de la Bégude
# ...                     ...                      ...
# Italy           White Blend    Feudi di San Gregorio
# France      Champagne Blend                H.Germain
# Italy           White Blend                Terredora
# France      Champagne Blend                   Gosset
# Italy          Pinot Grigio            Alois Lageder
#
# [150930 rows x 9 columns]

# %%
winedf2= winedf.loc[winedf.country == 'US']

# %%
winedf2
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 8           US  This re-named vineyard was formerly bottled as...
# 9           US  The producer sources from two blocks of the vi...
# ...        ...                                                ...
# 150892      US  A light, earthy wine, with violet, berry and t...
# 150896      US  Some raspberry fruit in the aroma, but things ...
# 150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916      US  An impressive wine that presents a full bouque...
#
#                           designation  points  price    province  \
# 0                   Martha's Vineyard      96  235.0  California
# 2       Special Selected Late Harvest      96   90.0  California
# 3                             Reserve      96   65.0      Oregon
# 8                              Silice      95   65.0      Oregon
# 9                Gap's Crown Vineyard      95   60.0  California
# ...                               ...     ...    ...         ...
# 150892                        Coastal      82   10.0  California
# 150896                            NaN      82   10.0  California
# 150914    Late Harvest Cluster Select      94   25.0  California
# 150915                    Nightingale      93   30.0  California
# 150916                      J. Schram      93   65.0  California
#
#                   region_1                 region_2             variety  \
# 0              Napa Valley                     Napa  Cabernet Sauvignon
# 2           Knights Valley                   Sonoma     Sauvignon Blanc
# 3        Willamette Valley        Willamette Valley          Pinot Noir
# 8       Chehalem Mountains        Willamette Valley          Pinot Noir
# 9             Sonoma Coast                   Sonoma          Pinot Noir
# ...                    ...                      ...                 ...
# 150892          California         California Other              Merlot
# 150896          California         California Other          Pinot Noir
# 150914     Anderson Valley  Mendocino/Lake Counties      White Riesling
# 150915         North Coast              North Coast         White Blend
# 150916         Napa Valley                     Napa     Champagne Blend
#
#              winery
# 0             Heitz
# 2          Macauley
# 3             Ponzi
# 8         Bergström
# 9         Blue Farm
# ...             ...
# 150892     Callaway
# 150896      Camelot
# 150914      Navarro
# 150915     Beringer
# 150916  Schramsberg
#
# [62397 rows x 10 columns]

# %%
winedf2['percentage'] = (winedf2['price']/winedf2['price'].sum())*100
winedf2
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12216\211765503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   winedf2['percentage'] = (winedf2['price']/winedf2['price'].sum())*100
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 8           US  This re-named vineyard was formerly bottled as...
# 9           US  The producer sources from two blocks of the vi...
# ...        ...                                                ...
# 150892      US  A light, earthy wine, with violet, berry and t...
# 150896      US  Some raspberry fruit in the aroma, but things ...
# 150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916      US  An impressive wine that presents a full bouque...
#
#                           designation  points  price    province  \
# 0                   Martha's Vineyard      96  235.0  California
# 2       Special Selected Late Harvest      96   90.0  California
# 3                             Reserve      96   65.0      Oregon
# 8                              Silice      95   65.0      Oregon
# 9                Gap's Crown Vineyard      95   60.0  California
# ...                               ...     ...    ...         ...
# 150892                        Coastal      82   10.0  California
# 150896                            NaN      82   10.0  California
# 150914    Late Harvest Cluster Select      94   25.0  California
# 150915                    Nightingale      93   30.0  California
# 150916                      J. Schram      93   65.0  California
#
#                   region_1                 region_2             variety  \
# 0              Napa Valley                     Napa  Cabernet Sauvignon
# 2           Knights Valley                   Sonoma     Sauvignon Blanc
# 3        Willamette Valley        Willamette Valley          Pinot Noir
# 8       Chehalem Mountains        Willamette Valley          Pinot Noir
# 9             Sonoma Coast                   Sonoma          Pinot Noir
# ...                    ...                      ...                 ...
# 150892          California         California Other              Merlot
# 150896          California         California Other          Pinot Noir
# 150914     Anderson Valley  Mendocino/Lake Counties      White Riesling
# 150915         North Coast              North Coast         White Blend
# 150916         Napa Valley                     Napa     Champagne Blend
#
#              winery  percentage
# 0             Heitz    0.011237
# 2          Macauley    0.004304
# 3             Ponzi    0.003108
# 8         Bergström    0.003108
# 9         Blue Farm    0.002869
# ...             ...         ...
# 150892     Callaway    0.000478
# 150896      Camelot    0.000478
# 150914      Navarro    0.001195
# 150915     Beringer    0.001435
# 150916  Schramsberg    0.003108
#
# [62397 rows x 11 columns]

# %%
winedfP = winedf2.loc[:,'price']

# %%
winedfP1 = pd.DataFrame[winedfP]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 winedfP1 = pd.DataFrame[winedfP]
#
# TypeError: 'type' object is not subscriptable

# %%
winedfp = pd.DataFrame(winedf2, columns= ['country','price'])
winedfp
# Out:
#        country  price
# 0           US  235.0
# 2           US   90.0
# 3           US   65.0
# 8           US   65.0
# 9           US   60.0
# ...        ...    ...
# 150892      US   10.0
# 150896      US   10.0
# 150914      US   25.0
# 150915      US   30.0
# 150916      US   65.0
#
# [62397 rows x 2 columns]

# %%
winedfp['percentage']= (winedfp['price']/winedfp['price'].sum())*100

# %%
winedfp
# Out:
#        country  price  percentage
# 0           US  235.0    0.011237
# 2           US   90.0    0.004304
# 3           US   65.0    0.003108
# 8           US   65.0    0.003108
# 9           US   60.0    0.002869
# ...        ...    ...         ...
# 150892      US   10.0    0.000478
# 150896      US   10.0    0.000478
# 150914      US   25.0    0.001195
# 150915      US   30.0    0.001435
# 150916      US   65.0    0.003108
#
# [62397 rows x 3 columns]

# %%
winedfp1 = pd.DataFrame(winedf2, columns= ['country','points'])
winedfp1
# Out:
#        country  points
# 0           US      96
# 2           US      96
# 3           US      96
# 8           US      95
# 9           US      95
# ...        ...     ...
# 150892      US      82
# 150896      US      82
# 150914      US      94
# 150915      US      93
# 150916      US      93
#
# [62397 rows x 2 columns]

# %%
winedf_avg = winedf[winedf['points'] > 90]
winedf_avg
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150923  France  Rich and toasty, with tiny bubbles. The bouque...
# 150924  France  Really fine for a low-acid vintage, there's an...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
#
#                                  designation  points  price        province  \
# 0                          Martha's Vineyard      96  235.0      California
# 1       Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2              Special Selected Late Harvest      96   90.0      California
# 3                                    Reserve      96   65.0          Oregon
# 4                                 La Brûlade      95   66.0        Provence
# ...                                      ...     ...    ...             ...
# 150923                              Demi-Sec      91   30.0       Champagne
# 150924                          Diamant Bleu      91   70.0       Champagne
# 150925                                   NaN      91   20.0  Southern Italy
# 150926                        Cuvée Prestige      91   27.0       Champagne
# 150927                         Terre di Dora      91   20.0  Southern Italy
#
#                  region_1           region_2             variety  \
# 0             Napa Valley               Napa  Cabernet Sauvignon
# 1                    Toro                NaN       Tinta de Toro
# 2          Knights Valley             Sonoma     Sauvignon Blanc
# 3       Willamette Valley  Willamette Valley          Pinot Noir
# 4                  Bandol                NaN  Provence red blend
# ...                   ...                ...                 ...
# 150923          Champagne                NaN     Champagne Blend
# 150924          Champagne                NaN     Champagne Blend
# 150925  Fiano di Avellino                NaN         White Blend
# 150926          Champagne                NaN     Champagne Blend
# 150927  Fiano di Avellino                NaN         White Blend
#
#                          winery
# 0                         Heitz
# 1       Bodega Carmen Rodríguez
# 2                      Macauley
# 3                         Ponzi
# 4          Domaine de la Bégude
# ...                         ...
# 150923                 Jacquart
# 150924  Heidsieck & Co Monopole
# 150925    Feudi di San Gregorio
# 150926                H.Germain
# 150927                Terredora
#
# [32237 rows x 10 columns]

# %%
winedf_avg2 = winedf[winedf['points'] < 90]
winedf_avg2
# Out:
#          country                                        description  \
# 90            US  Bright, light oak shadings dress up this mediu...
# 91      Portugal  The local Baga grape, better known for produci...
# 92         Italy  Aromas of white spring flower, orchard fruit a...
# 93            US  A smoky scent and earthy, crisp-apple flavors ...
# 94      Portugal  This family-owned estate has produced an immed...
# ...          ...                                                ...
# 150905     Chile  There's not much point in making a reserve-sty...
# 150909    France  This is a lovely, fragrant Burgundy, with a sm...
# 150910    France  Scents of graham cracker and malted milk choco...
# 150911    France  This needs a good bit of breathing time, then ...
# 150912    France  The nose is dominated by the attractive scents...
#
#                            designation  points  price         province  \
# 90                                 NaN      86   10.0       California
# 91      Marquês de Marialva Rosé Bruto      86   12.0  Beira Atlantico
# 92                              Nature      86   22.0           Veneto
# 93                     Small Lot Blend      86   13.0       California
# 94                      Muros de Vinha      86   10.0            Douro
# ...                                ...     ...    ...              ...
# 150905                   Prima Reserva      80   13.0     Maipo Valley
# 150909            Clos dea Argillieres      89   52.0         Burgundy
# 150910                             NaN      89   38.0         Burgundy
# 150911                    Les Chaliots      87   37.0         Burgundy
# 150912                     Les Charmes      87   65.0         Burgundy
#
#                  region_1                 region_2             variety  \
# 90             California         California Other  Cabernet Sauvignon
# 91                    NaN                      NaN                Baga
# 92               Prosecco                      NaN               Glera
# 93       Mendocino County  Mendocino/Lake Counties          Chardonnay
# 94                    NaN                      NaN      Portuguese Red
# ...                   ...                      ...                 ...
# 150905                NaN                      NaN              Merlot
# 150909  Nuits-St.-Georges                      NaN          Pinot Noir
# 150910  Chambolle-Musigny                      NaN          Pinot Noir
# 150911  Nuits-St.-Georges                      NaN          Pinot Noir
# 150912  Chambolle-Musigny                      NaN          Pinot Noir
#
#                      winery
# 90           Belle Ambiance
# 91      Adega de Cantanhede
# 92               De Stefani
# 93                 Parducci
# 94         Quinta do Portal
# ...                     ...
# 150905           De Martino
# 150909          Daniel Rion
# 150910          Michel Gros
# 150911          Michel Gros
# 150912          Daniel Rion
#
# [102720 rows x 10 columns]

# %%
# for all the countries
winedf_all = pd.DataFrame(winedf, columns= ['country','points'])
winedf_all
# Out:
#        country  points
# 0           US      96
# 1        Spain      96
# 2           US      96
# 3           US      96
# 4       France      95
# ...        ...     ...
# 150925   Italy      91
# 150926  France      91
# 150927   Italy      91
# 150928  France      90
# 150929   Italy      90
#
# [150930 rows x 2 columns]

# %%
winedf_all['percentage']= (winedf_all['points']/winedf_all['points'].sum())*100

# %%
winedf_all
# Out:
#        country  points  percentage
# 0           US      96    0.000724
# 1        Spain      96    0.000724
# 2           US      96    0.000724
# 3           US      96    0.000724
# 4       France      95    0.000716
# ...        ...     ...         ...
# 150925   Italy      91    0.000686
# 150926  France      91    0.000686
# 150927   Italy      91    0.000686
# 150928  France      90    0.000678
# 150929   Italy      90    0.000678
#
# [150930 rows x 3 columns]

# %%
winedf_all.describe()
# Out:
#               points     percentage
# count  150930.000000  150930.000000
# mean       87.888418       0.000663
# std         3.222392       0.000024
# min        80.000000       0.000603
# 25%        86.000000       0.000648
# 50%        88.000000       0.000663
# 75%        90.000000       0.000678
# max       100.000000       0.000754

# %%
newdf = winedf['country'].isin(['US'])

# %%
winedf[newdf]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 8           US  This re-named vineyard was formerly bottled as...
# 9           US  The producer sources from two blocks of the vi...
# ...        ...                                                ...
# 150892      US  A light, earthy wine, with violet, berry and t...
# 150896      US  Some raspberry fruit in the aroma, but things ...
# 150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916      US  An impressive wine that presents a full bouque...
#
#                           designation  points  price    province  \
# 0                   Martha's Vineyard      96  235.0  California
# 2       Special Selected Late Harvest      96   90.0  California
# 3                             Reserve      96   65.0      Oregon
# 8                              Silice      95   65.0      Oregon
# 9                Gap's Crown Vineyard      95   60.0  California
# ...                               ...     ...    ...         ...
# 150892                        Coastal      82   10.0  California
# 150896                            NaN      82   10.0  California
# 150914    Late Harvest Cluster Select      94   25.0  California
# 150915                    Nightingale      93   30.0  California
# 150916                      J. Schram      93   65.0  California
#
#                   region_1                 region_2             variety  \
# 0              Napa Valley                     Napa  Cabernet Sauvignon
# 2           Knights Valley                   Sonoma     Sauvignon Blanc
# 3        Willamette Valley        Willamette Valley          Pinot Noir
# 8       Chehalem Mountains        Willamette Valley          Pinot Noir
# 9             Sonoma Coast                   Sonoma          Pinot Noir
# ...                    ...                      ...                 ...
# 150892          California         California Other              Merlot
# 150896          California         California Other          Pinot Noir
# 150914     Anderson Valley  Mendocino/Lake Counties      White Riesling
# 150915         North Coast              North Coast         White Blend
# 150916         Napa Valley                     Napa     Champagne Blend
#
#              winery
# 0             Heitz
# 2          Macauley
# 3             Ponzi
# 8         Bergström
# 9         Blue Farm
# ...             ...
# 150892     Callaway
# 150896      Camelot
# 150914      Navarro
# 150915     Beringer
# 150916  Schramsberg
#
# [62397 rows x 10 columns]

# %%
newdf2= pd.DataFrame(newdf)
newdf2
# Out:
#         country
# 0          True
# 1         False
# 2          True
# 3          True
# 4         False
# ...         ...
# 150925    False
# 150926    False
# 150927    False
# 150928    False
# 150929    False
#
# [150930 rows x 1 columns]

# %%
newdf_or = winedf[(winedf.country == 'Italy')|(winedf.points > 90)]

# %%
newdf_or
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150924  France  Really fine for a low-acid vintage, there's an...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150924                          Diamant Bleu      91   70.0
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150924           Champagne          Champagne                NaN
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150924     Champagne Blend  Heidsieck & Co Monopole
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150929        Pinot Grigio            Alois Lageder
#
# [50513 rows x 10 columns]

# %%
winedf.notnull()
# Out:
#         country  description  designation  points  price  province  region_1  \
# 0          True         True         True    True   True      True      True
# 1          True         True         True    True   True      True      True
# 2          True         True         True    True   True      True      True
# 3          True         True         True    True   True      True      True
# 4          True         True         True    True   True      True      True
# ...         ...          ...          ...     ...    ...       ...       ...
# 150925     True         True        False    True   True      True      True
# 150926     True         True         True    True   True      True      True
# 150927     True         True         True    True   True      True      True
# 150928     True         True         True    True   True      True      True
# 150929     True         True        False    True   True      True      True
#
#         region_2  variety  winery
# 0           True     True    True
# 1          False     True    True
# 2           True     True    True
# 3           True     True    True
# 4          False     True    True
# ...          ...      ...     ...
# 150925     False     True    True
# 150926     False     True    True
# 150927     False     True    True
# 150928     False     True    True
# 150929     False     True    True
#
# [150930 rows x 10 columns]
